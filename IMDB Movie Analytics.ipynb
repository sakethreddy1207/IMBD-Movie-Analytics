# %%
pip install pandas mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: mysql-connector-python in d:\anaconda\lib\site-packages (9.6.0)
# Requirement already satisfied: sqlalchemy in d:\anaconda\lib\site-packages (2.0.43)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in d:\anaconda\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\anaconda\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- --------------------
# aiobotocore                       2.25.0
# aiodns                            3.5.0
# aiohappyeyeballs                  2.6.1
# aiohttp                           3.13.2
# aioitertools                      0.12.0
# aiosignal                         1.4.0
# alabaster                         0.7.16
# altair                            5.5.0
# anaconda-anon-usage               0.7.5
# anaconda-auth                     0.12.0
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.7.0
# anaconda-client                   1.14.0
# anaconda-navigator                2.7.0
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.10.0
# appdirs                           1.4.4
# archspec                          0.2.5
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              25.1.0
# arrow                             1.4.0
# astroid                           3.3.11
# astropy                           7.1.1
# astropy-iers-data                 0.2025.11.10.0.38.31
# asttokens                         3.0.0
# async-lru                         2.0.5
# asyncssh                          2.21.1
# atomicwrites                      1.4.0
# attrs                             25.4.0
# Automat                           24.8.1
# autopep8                          2.0.4
# babel                             2.17.0
# bcrypt                            5.0.0
# beautifulsoup4                    4.13.5
# binaryornot                       0.4.4
# black                             25.9.0
# bleach                            6.3.0
# blinker                           1.9.0
# bokeh                             3.8.0
# boltons                           25.0.0
# botocore                          1.40.46
# Bottleneck                        1.4.2
# brotlicffi                        1.1.0.0
# cachetools                        5.5.1
# cattrs                            25.3.0
# certifi                           2025.11.12
# cffi                              2.0.0
# chardet                           5.2.0
# charset-normalizer                3.4.4
# click                             8.2.1
# cloudpickle                       3.1.1
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.3
# conda                             25.11.0
# conda-anaconda-telemetry          0.3.0
# conda-anaconda-tos                0.2.2
# conda-build                       25.11.1
# conda-content-trust               0.2.0
# conda_index                       0.7.0
# conda-libmamba-solver             25.11.0
# conda-pack                        0.8.1
# conda-package-handling            2.4.0
# conda_package_streaming           0.12.0
# conda-repo-cli                    1.0.173
# constantly                        23.10.4
# contourpy                         1.3.3
# cookiecutter                      2.6.0
# cryptography                      46.0.3
# cssselect                         1.2.0
# cycler                            0.11.0
# dask                              2025.11.0
# datashader                        0.18.2
# debugpy                           1.8.16
# decorator                         5.2.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.4.0
# distributed                       2025.11.0
# distro                            1.9.0
# docstring-to-markdown             0.17
# docutils                          0.21.2
# et_xmlfile                        2.0.0
# evalidate                         2.0.3
# executing                         2.2.1
# fastjsonschema                    2.21.2
# filelock                          3.20.0
# flake8                            7.1.1
# Flask                             3.1.2
# fonttools                         4.60.1
# frozendict                        2.4.6
# frozenlist                        1.8.0
# fsspec                            2025.10.0
# gitdb                             4.0.12
# GitPython                         3.1.45
# gmpy2                             2.2.1
# greenlet                          3.2.4
# h11                               0.16.0
# h5py                              3.15.1
# HeapDict                          1.0.1
# holoviews                         1.22.0
# html5lib                          1.1
# httpcore                          1.0.9
# httpx                             0.28.1
# hvplot                            0.12.1
# hyperlink                         21.0.0
# idna                              3.11
# ImageIO                           2.37.2
# imagesize                         1.4.1
# imbalanced-learn                  0.14.0
# importlib_metadata                8.7.0
# incremental                       24.7.2
# inflection                        0.5.1
# iniconfig                         2.1.0
# intake                            2.0.8
# intervaltree                      3.1.0
# ipykernel                         6.31.0
# ipympl                            0.9.7
# ipython                           9.7.0
# ipython_pygments_lexers           1.1.1
# ipywidgets                        8.1.7
# isort                             6.1.0
# itemadapter                       0.12.1
# itemloaders                       1.3.2
# itsdangerous                      2.2.0
# jaraco.classes                    3.4.0
# jaraco.context                    0.0.0
# jaraco.functools                  4.1.0
# jedi                              0.19.2
# jellyfish                         1.2.1
# Jinja2                            3.1.6
# jmespath                          1.0.1
# joblib                            1.5.2
# json5                             0.12.1
# jsonpatch                         1.33
# jsonpointer                       3.0.0
# jsonschema                        4.25.0
# jsonschema-specifications         2025.9.1
# jupyter                           1.1.1
# jupyter_client                    8.6.3
# jupyter-console                   6.6.3
# jupyter_core                      5.8.1
# jupyter-events                    0.12.0
# jupyter-lsp                       2.2.5
# jupyter_server                    2.16.0
# jupyter_server_terminals          0.5.3
# jupyterlab                        4.4.7
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.28.0
# jupyterlab_widgets                3.0.15
# keyring                           25.7.0
# kiwisolver                        1.4.9
# lazy_loader                       0.4
# lckr_jupyterlab_variableinspector 3.2.4
# libarchive-c                      5.1
# libmambapy                        2.3.2
# lief                              0.16.4
# linkify-it-py                     2.0.3
# llvmlite                          0.45.1
# lmdb                              1.7.5
# locket                            1.0.0
# lsprotocol                        2025.0.0
# lxml                              5.3.0
# lz4                               4.4.5
# Markdown                          3.8
# markdown-it-py                    2.2.0
# MarkupSafe                        3.0.2
# matplotlib                        3.10.6
# matplotlib-inline                 0.2.1
# mccabe                            0.7.0
# mdit-py-plugins                   0.5.0
# mdurl                             0.1.2
# menuinst                          2.4.1
# mistune                           3.1.2
# mkl_fft                           2.1.1
# mkl_random                        1.3.0
# mkl-service                       2.5.2
# more-itertools                    10.8.0
# mpi4py                            4.0.3
# mpmath                            1.3.0
# msgpack                           1.1.1
# multidict                         6.7.0
# multipledispatch                  1.0.0
# mypy                              1.17.1
# mypy_extensions                   1.0.0
# mysql-connector-python            9.6.0
# narwhals                          2.7.0
# navigator-updater                 0.6.0
# nbclient                          0.10.2
# nbconvert                         7.16.6
# nbformat                          5.10.4
# nest_asyncio                      1.6.0
# networkx                          3.5
# nltk                              3.9.2
# notebook                          7.4.5
# notebook_shim                     0.2.4
# numba                             0.62.1
# numexpr                           2.14.1
# numpy                             2.3.5
# numpydoc                          1.9.0
# openpyxl                          3.1.5
# overrides                         7.7.0
# packaging                         25.0
# pandas                            2.3.3
# pandocfilters                     1.5.1
# panel                             1.8.3
# param                             2.3.0
# parsel                            1.10.0
# parso                             0.8.5
# partd                             1.4.2
# pathspec                          0.12.1
# patsy                             1.0.1
# pexpect                           4.9.0
# pickleshare                       0.7.5
# pillow                            12.0.0
# pip                               25.3
# pkce                              1.0.3
# pkginfo                           1.12.0
# platformdirs                      4.5.0
# plotly                            6.3.0
# pluggy                            1.5.0
# prometheus_client                 0.21.1
# prompt_toolkit                    3.0.52
# propcache                         0.3.1
# Protego                           0.4.0
# protobuf                          5.29.3
# psutil                            7.0.0
# ptyprocess                        0.7.0
# pure_eval                         0.2.3
# py-cpuinfo                        9.0.0
# pyarrow                           21.0.0
# pyasn1                            0.6.1
# pyasn1_modules                    0.4.2
# pycares                           4.10.0
# pycodestyle                       2.12.1
# pycosat                           0.6.6
# pycparser                         2.23
# pyct                              0.6.0
# pycurl                            7.45.7
# pydantic                          2.12.4
# pydantic_core                     2.41.5
# pydantic-settings                 2.12.0
# PyDispatcher                      2.0.7
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.5
# pyflakes                          3.2.0
# PyGithub                          2.8.1
# Pygments                          2.19.2
# PyJWT                             2.10.1
# pylint                            3.3.8
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.6.0
# pyodbc                            5.3.0
# pyOpenSSL                         25.3.0
# pyparsing                         3.2.5
# PyQt5                             5.15.11
# PyQt5_sip                         12.17.0
# PyQtWebEngine                     5.15.7
# PySide6                           6.9.2
# PySocks                           1.7.1
# pytest                            8.4.2
# python-dateutil                   2.9.0.post0
# python-dotenv                     1.1.0
# python-json-logger                3.2.1
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-ruff                   2.3.0
# python-lsp-server                 1.13.1
# python-slugify                    8.0.4
# pytokens                          0.3.0
# pytoolconfig                      1.2.6
# pytz                              2025.2
# pyuca                             1.2
# pyviz_comms                       3.0.6
# PyWavelets                        1.9.0
# pywin32                           311
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.15
# PyYAML                            6.0.3
# pyzmq                             27.1.0
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.4.0
# qtconsole                         5.7.0
# QtPy                              2.4.3
# queuelib                          1.8.0
# readchar                          4.2.1
# referencing                       0.37.0
# regex                             2025.9.1
# requests                          2.32.5
# requests-file                     2.1.0
# requests-toolbelt                 1.0.0
# rfc3339_validator                 0.1.4
# rfc3986_validator                 0.1.1
# rich                              14.2.0
# roman-numerals-py                 3.1.0
# rope                              1.14.0
# rpds-py                           0.28.0
# rtree                             1.4.1
# ruamel.yaml                       0.18.16
# ruamel.yaml.clib                  0.2.14
# ruamel_yaml_conda                 0.17.21
# ruff                              0.12.0
# s3fs                              2025.10.0
# scikit-image                      0.25.2
# scikit-learn                      1.7.2
# scipy                             1.16.3
# Scrapy                            2.13.3
# seaborn                           0.13.2
# semver                            3.0.4
# Send2Trash                        1.8.2
# service-identity                  24.2.0
# setuptools                        80.9.0
# shellingham                       1.5.4
# shiboken6                         6.9.2
# sip                               6.12.0
# six                               1.17.0
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   3.0.1
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            8.2.3
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# spyder                            6.1.0
# spyder-kernels                    3.1.1
# SQLAlchemy                        2.0.43
# stack_data                        0.6.3
# statsmodels                       0.14.5
# streamlit                         1.51.0
# superqt                           0.7.6
# sympy                             1.14.0
# tables                            3.10.2
# tabulate                          0.9.0
# tblib                             3.1.0
# tenacity                          9.1.2
# terminado                         0.18.1
# text-unidecode                    1.3
# textdistance                      4.6.3
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2025.10.4
# tinycss2                          1.4.0
# tldextract                        5.1.2
# toml                              0.10.2
# tomli                             2.2.1
# tomlkit                           0.13.3
# toolz                             1.0.0
# tornado                           6.5.1
# tqdm                              4.67.1
# traitlets                         5.14.3
# truststore                        0.10.1
# Twisted                           25.5.0
# twisted-iocpsupport               1.0.2
# typer                             0.17.4
# typing_extensions                 4.15.0
# typing-inspection                 0.4.2
# tzdata                            2025.2
# uc-micro-py                       1.0.3
# ujson                             5.11.0
# urllib3                           2.5.0
# w3lib                             2.3.1
# watchdog                          6.0.0
# wcwidth                           0.2.13
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.1.3
# whatthepatch                      1.0.7
# wheel                             0.45.1
# widgetsnbextension                4.0.14
# win_inet_pton                     1.1.0
# winloop                           0.3.1
# wrapt                             1.17.0
# xarray                            2025.10.1
# xlwings                           0.33.15
# xyzservices                       2025.4.0
# yapf                              0.43.0
# yarl                              1.22.0
# zict                              3.0.0
# zipp                              3.23.0
# zope.interface                    8.0.1
# zstandard                         0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("imdb_movies.csv")
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0          1.0     Movie 1  Thriller     4.2           100.0            NaN
# 1          2.0     Movie 2    Sci-Fi     7.8           150.0          150.0
# 2          3.0     Movie 3  Thriller     4.9            30.0          600.0
# 3          4.0     Movie 4  Thriller     9.1           100.0          600.0
# 4          5.0     Movie 5    Sci-Fi     4.5            10.0          600.0
# ...        ...         ...       ...     ...             ...            ...
# 5495    5496.0  Movie 5496    Horror     8.0             NaN           80.0
# 5496    5497.0  Movie 5497    Sci-Fi     7.4            30.0           20.0
# 5497    5498.0  Movie 5498    Sci-Fi     8.6            30.0           80.0
# 5498    5499.0  Movie 5499   Fantasy     6.3            10.0          600.0
# 5499    5500.0  Movie 5499   Romance     8.3            60.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 1         Nolan    Actor B        2019.0
# 2     Spielberg    Actor D        2016.0
# 3     Rajamouli    Actor D        2015.0
# 4       Cameron    Actor C        2022.0
# ...         ...        ...           ...
# 5495   Scorsese    Actor D        2021.0
# 5496    Cameron    Actor C        2016.0
# 5497  Spielberg    Actor A        2021.0
# 5498  Spielberg    Actor B        2019.0
# 5499      Nolan    Actor C           NaN
#
# [5500 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# movie_id          323
# title               0
# genre               0
# rating            289
# budget_million    931
# gross_million     917
# director          780
# lead_actor        914
# release_year      614
# dtype: int64

# %%
# Replace NaN gross temporarily for sorting
df['gross_temp'] = df['gross_million'].fillna(-1)

# Sort by business priority
df = df.sort_values(
    by=['title','release_year','rating','gross_temp'],
    ascending=[True,True,False,False]
)

# Drop duplicates keeping best record
df = df.drop_duplicates(subset=['title','release_year'], keep='first')

# Removing helper column
df=df.drop(columns=['gross_temp'])
df=df.reset_index(drop=True)
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0          1.0     Movie 1  Thriller     4.2           100.0            NaN
# 1         10.0    Movie 10    Sci-Fi     5.0             NaN           20.0
# 2       1001.0  Movie 1001    Comedy     6.4             NaN           20.0
# 3       1002.0  Movie 1002    Comedy     7.6            60.0          150.0
# 4          NaN  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468     996.0   Movie 996     Drama     4.5           150.0           80.0
# 5469     997.0   Movie 997    Horror     6.3           150.0          300.0
# 5470     998.0   Movie 998   Romance     6.9            10.0            NaN
# 5471    1000.0   Movie 999    Horror     8.0            10.0          600.0
# 5472     999.0   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron        NaN           NaN
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469        NaN    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
# Fill missing movie_id
missing_mask = df['movie_id'].isnull()

# Generate new surrogate keys
start_id = df['movie_id'].max() if df['movie_id'].notnull().any() else 0

df.loc[missing_mask, 'movie_id'] = range(int(start_id)+1, int(start_id)+1+missing_mask.sum())

# Ensure integer type
df['movie_id'] = df['movie_id'].astype(int)

# Ensure uniqueness
df = df.drop_duplicates(subset=['movie_id'])
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0            1     Movie 1  Thriller     4.2           100.0            NaN
# 1           10    Movie 10    Sci-Fi     5.0             NaN           20.0
# 2         1001  Movie 1001    Comedy     6.4             NaN           20.0
# 3         1002  Movie 1002    Comedy     7.6            60.0          150.0
# 4         5501  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468       996   Movie 996     Drama     4.5           150.0           80.0
# 5469       997   Movie 997    Horror     6.3           150.0          300.0
# 5470       998   Movie 998   Romance     6.9            10.0            NaN
# 5471      1000   Movie 999    Horror     8.0            10.0          600.0
# 5472       999   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron        NaN           NaN
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469        NaN    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
# Remove invalid ratings
df.loc[(df['rating'] < 0) | (df['rating'] > 10), 'rating'] = np.nan

# Calculate averages
genre_avg_rating = df.groupby('genre')['rating'].transform('mean')
global_avg_rating = df['rating'].mean()

# Fill missing
df['rating'] = df['rating'].fillna(genre_avg_rating)
df['rating'] = df['rating'].fillna(global_avg_rating)
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0            1     Movie 1  Thriller     4.2           100.0            NaN
# 1           10    Movie 10    Sci-Fi     5.0             NaN           20.0
# 2         1001  Movie 1001    Comedy     6.4             NaN           20.0
# 3         1002  Movie 1002    Comedy     7.6            60.0          150.0
# 4         5501  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468       996   Movie 996     Drama     4.5           150.0           80.0
# 5469       997   Movie 997    Horror     6.3           150.0          300.0
# 5470       998   Movie 998   Romance     6.9            10.0            NaN
# 5471      1000   Movie 999    Horror     8.0            10.0          600.0
# 5472       999   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron        NaN           NaN
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469        NaN    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
# Remove invalid budgets
df.loc[df['budget_million'] < 0, 'budget_million'] = np.nan

# Calculate medians
genre_median_budget = df.groupby('genre')['budget_million'].transform('median')
overall_median_budget = df['budget_million'].median()

# Fill missing
df['budget_million'] = df['budget_million'].fillna(genre_median_budget)
df['budget_million'] = df['budget_million'].fillna(overall_median_budget)
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0            1     Movie 1  Thriller     4.2           100.0            NaN
# 1           10    Movie 10    Sci-Fi     5.0            60.0           20.0
# 2         1001  Movie 1001    Comedy     6.4            60.0           20.0
# 3         1002  Movie 1002    Comedy     7.6            60.0          150.0
# 4         5501  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468       996   Movie 996     Drama     4.5           150.0           80.0
# 5469       997   Movie 997    Horror     6.3           150.0          300.0
# 5470       998   Movie 998   Romance     6.9            10.0            NaN
# 5471      1000   Movie 999    Horror     8.0            10.0          600.0
# 5472       999   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron        NaN           NaN
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469        NaN    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
# Remove negative gross
df.loc[df['gross_million'] < 0, 'gross_million'] = 0

# Replace null with 0
df['gross_million'] = df['gross_million'].fillna(0)

df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0            1     Movie 1  Thriller     4.2           100.0            0.0
# 1           10    Movie 10    Sci-Fi     5.0            60.0           20.0
# 2         1001  Movie 1001    Comedy     6.4            60.0           20.0
# 3         1002  Movie 1002    Comedy     7.6            60.0          150.0
# 4         5501  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468       996   Movie 996     Drama     4.5           150.0           80.0
# 5469       997   Movie 997    Horror     6.3           150.0          300.0
# 5470       998   Movie 998   Romance     6.9            10.0            0.0
# 5471      1000   Movie 999    Horror     8.0            10.0          600.0
# 5472       999   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron        NaN           NaN
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469        NaN    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
df['lead_actor']=df['lead_actor'].fillna("Unknown")
df['director']=df['director'].fillna("Unknown")
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0            1     Movie 1  Thriller     4.2           100.0            0.0
# 1           10    Movie 10    Sci-Fi     5.0            60.0           20.0
# 2         1001  Movie 1001    Comedy     6.4            60.0           20.0
# 3         1002  Movie 1002    Comedy     7.6            60.0          150.0
# 4         5501  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468       996   Movie 996     Drama     4.5           150.0           80.0
# 5469       997   Movie 997    Horror     6.3           150.0          300.0
# 5470       998   Movie 998   Romance     6.9            10.0            0.0
# 5471      1000   Movie 999    Horror     8.0            10.0          600.0
# 5472       999   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron    Unknown        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron    Unknown           NaN
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469    Unknown    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# movie_id            0
# title               0
# genre               0
# rating              0
# budget_million      0
# gross_million       0
# director            0
# lead_actor          0
# release_year      610
# dtype: int64

# %%
genre_year = df.groupby('genre')['release_year'].transform('median')
overall_median_year =df['release_year'].median()
df['release_year'] = df['release_year'].fillna(genre_year)
df['release_year'] = df['release_year'].fillna(overall_median_year)
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0            1     Movie 1  Thriller     4.2           100.0            0.0
# 1           10    Movie 10    Sci-Fi     5.0            60.0           20.0
# 2         1001  Movie 1001    Comedy     6.4            60.0           20.0
# 3         1002  Movie 1002    Comedy     7.6            60.0          150.0
# 4         5501  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 5468       996   Movie 996     Drama     4.5           150.0           80.0
# 5469       997   Movie 997    Horror     6.3           150.0          300.0
# 5470       998   Movie 998   Romance     6.9            10.0            0.0
# 5471      1000   Movie 999    Horror     8.0            10.0          600.0
# 5472       999   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron    Unknown        2017.0
# 1     Spielberg    Actor B        2019.0
# 2     Rajamouli    Actor D        2021.0
# 3       Cameron    Unknown        2019.0
# 4     Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 5468    Cameron    Actor B        2020.0
# 5469    Unknown    Actor B        2019.0
# 5470      Nolan    Actor B        2022.0
# 5471  Tarantino    Actor A        2019.0
# 5472    Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %%
from sqlalchemy import create_engine

engine=create_engine(
    "mysql+mysqlconnector://root:saketh reddy@localhost:3306/imdb_analysis"
)

engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost:3306/imdb_analysis)

# %%
df.to_sql(
    name="movies",
    con=engine,
    if_exists="replace",
    index=False
)
print("ETL Load Completed")
# Out:
# ETL Load Completed

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:saketh reddy@localhost:3306/imdb_analysis")

query = """
SELECT release_year, title, gross_million
FROM (
    SELECT 
        release_year,
        title,
        gross_million,
        ROW_NUMBER() OVER (
            PARTITION BY release_year 
            ORDER BY gross_million DESC
        ) AS rank_no
    FROM movies
) ranked
WHERE rank_no <= 10;
"""

df1 = pd.read_sql(query, engine)

plt.figure()
plt.bar(df1["release_year"].astype(str), df1["gross_million"])
plt.title("Top 10 Highest Grossing Movies by Year")
plt.xlabel("Year")
plt.ylabel("gross_million")
plt.xticks(rotation=90)
plt.show()

# %%
query = """
SELECT genre, AVG(rating) AS avg_rating
FROM movies
GROUP BY genre;
"""

df2 = pd.read_sql(query, engine)

plt.figure()
plt.plot(df2["genre"], df2["avg_rating"])
plt.title("Average Rating by Genre")
plt.xlabel("Genre")
plt.ylabel("Average Rating")
plt.show()

# %%
query = """
SELECT director, AVG(rating) AS avg_rating
FROM movies
where director <> 'Unknown'
GROUP BY director
ORDER BY avg_rating DESC
LIMIT 5;
"""

df3 = pd.read_sql(query, engine)

plt.figure()
plt.plot(df3["director"], df3["avg_rating"])
plt.title("Top 5 Directors by Average Rating")
plt.xlabel("Director")
plt.ylabel("Average Rating")
plt.show()

# %%
query = """
SELECT budget_million, gross_million
FROM movies
WHERE budget_million IS NOT NULL
AND gross_million IS NOT NULL;
"""

df4 = pd.read_sql(query, engine)

plt.figure(figsize=(8,6))

plt.scatter(df4["budget_million"], df4["gross_million"])

# regression line
z = np.polyfit(df4["budget_million"], df4["gross_million"], 1)
p = np.poly1d(z)

plt.plot(df4["budget_million"], p(df4["budget_million"]))

plt.title("Budget vs Gross Correlation")
plt.xlabel("Budget (Million)")
plt.ylabel("Gross (Million)")

plt.show()

# %%
query = """
SELECT genre, SUM(gross_million - budget_million) AS total_profit
FROM movies
GROUP BY genre
ORDER BY total_profit DESC;
"""

df5 = pd.read_sql(query, engine)

plt.figure()
plt.bar(df5["genre"], df5["total_profit"])
plt.title("Most Profitable Genre")
plt.xlabel("Genre")
plt.ylabel("Total Profit")
plt.show()

print("Most Profitable Genre:", df5.iloc[0]["genre"])
# Out:
# Most Profitable Genre: Fantasy
